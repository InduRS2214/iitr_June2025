# %%
# A node’s value attribute tells you how many training instances of each class this node applies to - TRue

# A Gini coefficient of 1 expresses maximal inequality among the training samples - True

# A decision tree estimates the probability that an instance belongs to a particular class k by finding the corresponding 
# leaf node for the instance and then returning the ratio of training instances of class k - True

# The CART algorithm splits the training set in two subsets Using a single feature k and a threshold tk

# How does the CART algorithm chooses the feature k and the threshold tk for splitting ?
#Ans: It chooses the feature k and threshold tk which produces the purest subsets

# The cost function for finding the value of feature k and threshold tk takes into consideration
#Ans: The Gini index values of the subsets, The number of instances in the subsets & The total number of instances in 
# the node that is being split

# The CART algorithm stops recursion once it reaches the maximum depth (defined by the max_depth hyperparameter), or 
# if it cannot find a split that will reduce impurity - True

# While making a prediction in Decision Tree, each node only requires checking the value of one feature - True

# If the total number of training instances is m then the overall complexity of prediction of decision trees is O(log(m))

# If the number of features in n and number of training set instances is m then the complexity of training of a decision 
# tree is O(nmlog(m))

# For regression tasks the CART algorithm tries to split the training set in a way that minimizes the MSE - True
