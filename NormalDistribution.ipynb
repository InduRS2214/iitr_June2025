# %%
import numpy as np

def random_sd(sd, mean, count_dp):
    num_arr = []
    while(len(num_arr) <= count_dp):
        x = 10 * np.random.rand() - 5
        prob_x = (np.exp(-(x - mean)**2 / (2 * sd**2))) / (sd * np.sqrt(2 * np.pi))
    return num

random_sd(5)
# Out:
# array([ 0.14609276, -4.44241879,  3.61883395,  4.46745522,  1.76228186,
#         0.18148301,  2.97615774,  0.36149834, -3.67111456, -4.05891166])

# %%
num_arr = []
for i in range(0,5):
    num_arr.append(i)
print(len(num_arr))
# Out:
# 5

# %%
10 * np.random.rand() - 5
# Out:
# 2.151127601215684

# %%
num_arr = np.array(count_dp)
