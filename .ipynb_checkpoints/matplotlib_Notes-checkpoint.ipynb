# %%
import matplotlib.pyplot as plt

plt.plot([4,2,3,5])
plt.ylabel("NOS")
plt.show()

# %%
plt.plot([2,4,6,8],[0,1,2,3]) #plot(<X-Axis>,<Y-Axis>) where x & y values should be arrays
plt.ylabel("NOS")
plt.show()

# %%
x = [3,6,100,334,565,34,7,58,767,68,57,466,213,200,278,275,354,385,403,566]
division_y = 5 #tells Matplotlib to divide the data range of x into 5 equal intervals (bins) 
# and count how many values fall into each interval.
plt.hist(x, division_y, facecolor='green')
plt.show()
