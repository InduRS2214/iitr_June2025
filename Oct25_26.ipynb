# %%
import matplotlib.pyplot as plt

img = plt.imread('pexels-cmrcn-27799203.jpg')
type(img)
img.shape
img[0][0]
plt.imshow(img)

# %%
plt.imshow(img[2000:3000, 1000:2000, :])

# %%
plt.imshow(gray_scale, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.imshow(gray_scale, cmap='gray')
#
# NameError: name 'gray_scale' is not defined
